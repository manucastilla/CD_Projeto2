# %% [markdown]
# gfdg

# %%
#Primeiramente importamos para poder realizar o código
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nike = pd.read_excel('tweets_nike_201809042210.xlsx')
nike_treinamento =nike["Treinamento"]
nike.head(2)
# Out:
#                                          Treinamento  Valor_(R(1)_I(0))  \
# 0  @floydy1983  save big with joyhunt-up to 80% o...                  1
# 1  rt @virgilableaux: hi. former us navy sailor h...                  1
#
#    Positivo(1)/Negativo(0)
# 0                      1.0
# 1                      1.0

# %%
# tirar virgula
sopa = "  ".join(list(nike.Treinamento))
split_sopa = sopa.split()

# %%
import nltk
print(string.punctuation)

# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
pelado = [w.translate(table) for w in split_sopa]
print(pelado)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# ['floydy1983', 'save', 'big', 'with', 'joyhuntup', 'to', '80', 'off', 'rpp', 'on', 'great', 'brands', 'such', 'as', 'ralph', 'lauren', 'michael', 'kors', 'armani', 'adidas', 'marc', 'jacobs', 'missguided', 'hugo', 'boss', 'nike', 'lacoste', 'vans', 'anä�', 'many', 'more', 'see', 'for', 'yourselfdownload', 'for', 'free', 'today', '', 'httpstcocwanm0dayx', 'rt', 'virgilableaux', 'hi', 'former', 'us', 'navy', 'sailor', 'here', 'wondering', 'if', 'he', 'has', 'any', 'other', 'nike', 'gear', 'he', 'wants', 'to', 'get', 'rid', 'of', 'i', 'know', 'a', 'few', 'places', 'i', 'co…', 'boycottnike', 'i', 'think', 'a', 'great', 'big', 'thank', 'you', 'nike', 'from', 'under', 'armor', 'adidas', 'reebok', 'and', 'converse', 'is', 'in', 'order', 'rt', 'thedonholly', 'if', 'you', 'plan', 'on', 'boycotting', 'nike', 'i', 'will', 'dispose', 'of', 'all', 'of', 'your', 'clothing', 'items', 'for', 'free', 'just', 'hit', 'my', 'dm’s', 'i', 'have', 'a', 'school', 'fu…', 'rt', 'tonestradamus', 'when', 'they', 'start', 'boycotting', 'nike', 'so', 'my', 'size', 'is', 'always', 'available', 'in', 'every', 'shoe', 'httpstcogi4ipiu4xg', 'nike', 'stock', 'plunges', 'after', 'tapping', 'kaepernick', 'as', 'just', 'do', 'it', 'campaign', 'poster', 'boy', 'httpstcowabuzhwehb', 'trending', 'via', 'pjmediacom', 'rt', 'cnn', 'the', 'nfl', 'releases', 'a', 'statement', 'a', 'day', 'after', 'nike', 'announces', 'a', 'new', 'deal', 'with', 'colin', 'kaepernick', 'the', 'social', 'justice', 'issues', 'that', 'colin', 'an…', 'rt', 'meluhnen', 'y’all', 'ready', 'to', 'boycott', 'nike', 'over', 'a', 'black', 'man', 'but', 'won’t', 'boycott', 'catholic', 'churches', 'for', 'fucking', 'y’all', 'kids', 'nike', 'eat', 'shit', 'assholes', 'loving', 'nike', 'even', 'more', 'than', 'i', 'ever', 'did', '❤️', 'runnain', 'stoptrump20', 'newyorkphotogal', 'nike', 'pays', 'big', 'rent', 'to', 'him', 'rt', 'meluhnen', 'y’all', 'ready', 'to', 'boycott', 'nike', 'over', 'a', 'black', 'man', 'but', 'won’t', 'boycott', 'catholic', 'churches', 'for', 'fucking', 'y’all', 'kids', 'rt', 'umcornell', 'nike', 'makes', 'colin', 'kaepernick', 'the', 'face', 'of', 'their', 'brand', 'racists', 'httpstcohm25xno1io', 'rt', 'tonestradamus', 'when', 'they', 'start', 'boycotting', 'nike', 'so', 'my', 'size', 'is', 'always', 'available', 'in', 'every', 'shoe', 'httpstcogi4ipiu4xg', 'rt', 'juicylorr', 'nike', 'said', 'they', 'want', 'all', 'the', 'smoke', 'all', '2019', '🔥🔥🔥', 'freesmoke', 'httpstcou33gurezaw', 'rt', 'cabotphillips', 'i', 'dunno', 'what', 'everyone', 'is', 'talking', 'about', 'i', 'see', 'no', 'problems', 'with', 'nikes', 'new', 'ad', 'campaign', 'httpstcoio30eguf19', 'rt', 'tonyjefferson', 'instead', 'of', 'burning', 'your', 'nike', 'gear', 'give', 'it', 'to', 'the', 'people', 'who', 'need', 'clothingshoes', 'etc', '🤷🏾\u200d♂️', 'rt', 'umcornell', 'nike', 'makes', 'colin', 'kaepernick', 'the', 'face', 'of', 'their', 'brand', 'racists', 'httpstcohm25xno1io', 'rt', 'aasian', 'nike', 'watching', 'y’all', 'burn', 'your', 'nike', 'gear', 'that', 'you', 'already', 'paid', 'for', 'httpstcourawfh0ym0', 'rt', 'blackalvin3', 'nike', 'sue', 'her', 'for', 'using', 'your', 'logo', 'without', 'express', 'permission', 'httpstcoo9twjsrkfi', 'woooaaahcam', 'nike', 'you', 'got', 'the', 'pdf', 'file', 'of', 'the', 'joint', 'still', 'rt', 'tmillerpoetry', 'nike', 'about', 'to', 'be', 'be', 'the', 'only', 'n', 'word', 'white', 'people', 'stop', 'saying', 'what', 'has', 'kapernick', 'done', 'in', 'the', 'past', '2', 'yrs', 'to', 'make', 'a', 'difference', 'in', 'the', 'black', 'community', 'is', 'he', 'donating', 'his', 'nike', 'salary', 'creating', 'educational', 'prorams', 'chicago', 'la', 'rt', 'joel9one', 'nike', 'is', 'a', 'huge', 'business', 'they’ve', 'calculated', 'risk', 'they', 'may', 'even', 'have', 'reason', 'to', 'believe', 'this', 'will', 'make', 'the', 'brand', 'more', 'popular…', 'rt', 'duszalukasz', 'nike', 'factory', 'workers', 'are', 'making', 'shoes', 'for', '20', 'cents', 'an', 'hour',  ...

# %%
#!/usr/bin/env python
import re

text = pelado
#print(text) # with emoji

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
print(emoji_pattern.sub(r'', text)) # no emoji
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-2967200eb500> in <module>()
#      11         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#      12                            "]+", flags=re.UNICODE)
# ---> 13 print(emoji_pattern.sub(r'', text)) # no emoji
#
# TypeError: expected string or bytes-like object

# %%
#tirar os sinais

#for palavra in split_sopa:
dicio_geral ={}

# criar um dicionario
for palavra in pelado: 
    if palavra in dicio_geral:
        dicio_geral[palavra]+=1
    else:
        dicio_geral[palavra]=1

# %%
tweet = nike["Treinamento]

dicio_R={}
dicio_I={}
for o in nike["Valor_(R(1)_I(0))"]:
    if o == 1:
        dicio_R[o] = tweet[o]
    else:
        dicio_I[o] = tweet[o]
dicio_R
# Out:
# {1: 'rt @virgilableaux: hi. former us navy sailor here. wondering if he has any other nike gear he wants to get rid of. i know a few places i co…'}

# %% [markdown]
# ## referências
# https://machinelearningmastery.com/clean-text-machine-learning-python/
